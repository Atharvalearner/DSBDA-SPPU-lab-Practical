# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
at = pd.read_csv(r"C:\Users\Shree\Desktop\atharva\DSBDA\datasets\AirQuality_visualization.csv",sep=';')
at
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9466            NaN      NaN           NaN      NaN           NaN
# 9467            NaN      NaN           NaN      NaN           NaN
# 9468            NaN      NaN           NaN      NaN           NaN
# 9469            NaN      NaN           NaN      NaN           NaN
# 9470            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3)     T    RH      AH  Unnamed: 15  Unnamed: 16
# 0          1268.0  13,6  48,9  0,7578          NaN          NaN
# 1           972.0  13,3  47,7  0,7255          NaN          NaN
# 2          1074.0  11,9  54,0  0,7502          NaN          NaN
# 3          1203.0  11,0  60,0  0,7867          NaN          NaN
# 4          1110.0  11,2  59,6  0,7888          NaN          NaN
# ...           ...   ...   ...     ...          ...          ...
# 9466          NaN   NaN   NaN     NaN          NaN          NaN
# 9467          NaN   NaN   NaN     NaN          NaN          NaN
# 9468          NaN   NaN   NaN     NaN          NaN          NaN
# 9469          NaN   NaN   NaN     NaN          NaN          NaN
# 9470          NaN   NaN   NaN     NaN          NaN          NaN
#
# [9471 rows x 17 columns]

# %%
at = at.rename(columns={'T': 'Temperature'})
at = at.rename(columns={'RH': 'Relative Humidity'})
at = at.rename(columns={'AH': 'Absolute Humidity'})
at
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9466            NaN      NaN           NaN      NaN           NaN
# 9467            NaN      NaN           NaN      NaN           NaN
# 9468            NaN      NaN           NaN      NaN           NaN
# 9469            NaN      NaN           NaN      NaN           NaN
# 9470            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3) Temperature Relative Humidity Absolute Humidity  \
# 0          1268.0        13,6              48,9            0,7578
# 1           972.0        13,3              47,7            0,7255
# 2          1074.0        11,9              54,0            0,7502
# 3          1203.0        11,0              60,0            0,7867
# 4          1110.0        11,2              59,6            0,7888
# ...           ...         ...               ...               ...
# 9466          NaN         NaN               NaN               NaN
# 9467          NaN         NaN               NaN               NaN
# 9468          NaN         NaN               NaN               NaN
# 9469          NaN         NaN               NaN               NaN
# 9470          NaN         NaN               NaN               NaN
#
#       Unnamed: 15  Unnamed: 16
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 9466          NaN          NaN
# 9467          NaN          NaN
# 9468          NaN          NaN
# 9469          NaN          NaN
# 9470          NaN          NaN
#
# [9471 rows x 17 columns]

# %%
at['CO(GT)'] = at['CO(GT)'].str.replace(',', '.').astype(float)
at['C6H6(GT)'] = at['C6H6(GT)'].str.replace(',', '.').astype(float)
at['Temperature'] = at['Temperature'].str.replace(',', '.').astype(float)
at['Relative Humidity'] = at['Relative Humidity'].str.replace(',', '.').astype(float)
at['Absolute Humidity'] = at['Absolute Humidity'].str.replace(',', '.').astype(float)

# %%
at
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9466            NaN      NaN           NaN      NaN           NaN
# 9467            NaN      NaN           NaN      NaN           NaN
# 9468            NaN      NaN           NaN      NaN           NaN
# 9469            NaN      NaN           NaN      NaN           NaN
# 9470            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3)  Temperature  Relative Humidity  Absolute Humidity
# 0          1268.0         13.6               48.9             0.7578
# 1           972.0         13.3               47.7             0.7255
# 2          1074.0         11.9               54.0             0.7502
# 3          1203.0         11.0               60.0             0.7867
# 4          1110.0         11.2               59.6             0.7888
# ...           ...          ...                ...                ...
# 9466          NaN          NaN                NaN                NaN
# 9467          NaN          NaN                NaN                NaN
# 9468          NaN          NaN                NaN                NaN
# 9469          NaN          NaN                NaN                NaN
# 9470          NaN          NaN                NaN                NaN
#
# [9471 rows x 15 columns]

# %%
at=at.drop_duplicates()
at.isna().sum()
# Out:
# Date                 1
# Time                 1
# CO(GT)               1
# PT08.S1(CO)          1
# NMHC(GT)             1
# C6H6(GT)             1
# PT08.S2(NMHC)        1
# NOx(GT)              1
# PT08.S3(NOx)         1
# NO2(GT)              1
# PT08.S4(NO2)         1
# PT08.S5(O3)          1
# Temperature          1
# Relative Humidity    1
# Absolute Humidity    1
# dtype: int64

# %%
at = at.fillna(at.mean())
at = at.dropna()
at.isna().sum()
# Out:
# C:\Users\Shree\AppData\Local\Temp\ipykernel_13560\32326526.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   at = at.fillna(at.mean())
# Date                 0
# Time                 0
# CO(GT)               0
# PT08.S1(CO)          0
# NMHC(GT)             0
# C6H6(GT)             0
# PT08.S2(NMHC)        0
# NOx(GT)              0
# PT08.S3(NOx)         0
# NO2(GT)              0
# PT08.S4(NO2)         0
# PT08.S5(O3)          0
# Temperature          0
# Relative Humidity    0
# Absolute Humidity    0
# dtype: int64

# %%
at
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0    -200.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0    -200.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0    -200.0       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)  Temperature  Relative Humidity  Absolute Humidity
# 0          1268.0         13.6               48.9             0.7578
# 1           972.0         13.3               47.7             0.7255
# 2          1074.0         11.9               54.0             0.7502
# 3          1203.0         11.0               60.0             0.7867
# 4          1110.0         11.2               59.6             0.7888
# ...           ...          ...                ...                ...
# 9352       1729.0         21.9               29.3             0.7568
# 9353       1269.0         24.3               23.7             0.7119
# 9354       1092.0         26.9               18.3             0.6406
# 9355        770.0         28.3               13.5             0.5139
# 9356        816.0         28.5               13.1             0.5028
#
# [9357 rows x 15 columns]

# %%
sns.scatterplot(x='PT08.S1(CO)', y='NMHC(GT)', data=at[:80])
plt.title('Temperature vs. Area')
plt.xlabel('Temperature')
plt.ylabel('Area')
# Out:
# Text(0, 0.5, 'Area')

# %%
sns.countplot(x='NMHC(GT)', data=at[:10])
# Out:
# <Axes: xlabel='NMHC(GT)', ylabel='count'>

# %%
sns.kdeplot(data=at['PT08.S1(CO)'])
plt.title('Kernel Density Estimate of NMHC(GT)')
plt.xlabel('NMHC(GT)')
# Out:
# Text(0.5, 0, 'NMHC(GT)')

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=at[:1000], x='PT08.S1(CO)')
# Out:
# <Axes: xlabel='PT08.S1(CO)', ylabel='Count'>

# %%
sns.barplot(data=at[:80], x='PT08.S1(CO)', y='NMHC(GT)', errorbar=None)
# Out:
# <Axes: xlabel='PT08.S1(CO)', ylabel='NMHC(GT)'>

# %%
sns.boxplot(x='PT08.S1(CO)', y='NMHC(GT)', data=at[:5])
# Out:
# <Axes: xlabel='PT08.S1(CO)', ylabel='NMHC(GT)'>

# %%
plt.figure(figsize=(10, 8))
corr = at.corr()
sns.heatmap(corr, annot=True, cmap='YlGn')
# Out:
# C:\Users\Shree\AppData\Local\Temp\ipykernel_13560\37400349.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = at.corr()
# <Axes: >

# %%
sns.lineplot(data=at[:35], x='PT08.S1(CO)', y='NMHC(GT)', estimator='mean')
plt.grid(True)
