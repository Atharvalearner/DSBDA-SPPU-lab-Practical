# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
at = pd.read_csv(r"C:\Users\Shree\Desktop\atharva\DSBDA\datasets\forestfire.csv")
at
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
plt.figure(figsize=(10,6))
plt.hist(at['temp'],bins=10,color='skyblue',edgecolor='black')
plt.xlabel('temp')
plt.ylabel('freq')
plt.title('frequency vs tempurature')
plt.show()

# %%
plt.figure(figsize=(8, 8))
counts = at['day'].value_counts()
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']   
plt.pie(counts, labels=days, autopct='%1.1f%%')
plt.title('Distribution of Forest Fires by Day of the Week')
plt.show()

# %%
 # Line Graph
# x = at[:10,:]
plt.figure(figsize=(10, 6))
plt.plot(at[:25]['temp'], label='Temperatue', linestyle='-', color='green')
plt.xlabel('Sample')
plt.ylabel('Temperature')
plt.title('Temperature over Samples')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(at['day'], at['area'], color='orange', alpha=0.8)
plt.title('Day vs. Area Affected')
plt.xlabel('Day')
plt.ylabel('Area Affected')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.boxplot([at['rain'],at['wind'],at['temp']],labels=['temp','wind','rain'])
plt.title('Variation in Fire Weather Indices by Month')
plt.xlabel('Fire Weather Indices')
plt.ylabel('Values')
plt.grid(True)
plt.show()
